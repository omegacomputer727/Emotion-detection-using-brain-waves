# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data = pd.read_csv("emotions.csv")
data
# Out:
#       # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  \
# 0          4.620      30.3    -356.0     15.60      26.3       1.070
# 1         28.800      33.1      32.0     25.80      22.8       6.550
# 2          8.900      29.4    -416.0     16.70      23.7      79.900
# 3         14.900      31.6    -143.0     19.80      24.3      -0.584
# 4         28.300      31.3      45.2     27.30      24.5      34.800
# ...          ...       ...       ...       ...       ...         ...
# 2127      32.400      32.2      32.2     30.80      23.4       1.640
# 2128      16.300      31.3    -284.0     14.30      23.9       4.200
# 2129      -0.547      28.3    -259.0     15.80      26.7       9.080
# 2130      16.800      19.9    -288.0      8.34      26.0       2.460
# 2131      27.000      32.0      31.8     25.00      28.9       4.990
#
#       mean_d_1_a  mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  \
# 0          0.411     -15.700       2.060        3.15  ...      23.50
# 1          1.680       2.880       3.830       -4.82  ...     -23.30
# 2          3.360      90.200      89.900        2.03  ...     462.00
# 3         -0.284       8.820       2.300       -1.97  ...     299.00
# 4         -5.790       3.060      41.400        5.52  ...      12.00
# ...          ...         ...         ...         ...  ...        ...
# 2127      -2.030       0.647      -0.121       -1.10  ...     -21.70
# 2128       1.090       4.460       4.720        6.63  ...     594.00
# 2129       6.900      12.700       2.030        4.64  ...     370.00
# 2130       1.580     -16.000       1.690        4.74  ...     124.00
# 2131       1.950       6.210       3.490       -3.51  ...       1.95
#
#       fft_742_b  fft_743_b  fft_744_b  fft_745_b  fft_746_b  fft_747_b  \
# 0        20.300     20.300      23.50     -215.0     280.00    -162.00
# 1       -21.800    -21.800     -23.30      182.0       2.57     -31.60
# 2      -233.000   -233.000     462.00     -267.0     281.00    -148.00
# 3      -243.000   -243.000     299.00      132.0     -12.40       9.53
# 4        38.100     38.100      12.00      119.0     -17.60      23.90
# ...         ...        ...        ...        ...        ...        ...
# 2127      0.218      0.218     -21.70       95.2     -19.90      47.20
# 2128   -324.000   -324.000     594.00      -35.5     142.00     -59.80
# 2129   -160.000   -160.000     370.00      408.0    -169.00     -10.50
# 2130    -27.600    -27.600     124.00     -656.0     552.00    -271.00
# 2131      1.810      1.810       1.95      110.0      -6.71      22.80
#
#       fft_748_b  fft_749_b     label
# 0       -162.00     280.00  NEGATIVE
# 1        -31.60       2.57   NEUTRAL
# 2       -148.00     281.00  POSITIVE
# 3          9.53     -12.40  POSITIVE
# 4         23.90     -17.60   NEUTRAL
# ...         ...        ...       ...
# 2127      47.20     -19.90   NEUTRAL
# 2128     -59.80     142.00  POSITIVE
# 2129     -10.50    -169.00  NEGATIVE
# 2130    -271.00     552.00  NEGATIVE
# 2131      22.80      -6.71   NEUTRAL
#
# [2132 rows x 2549 columns]

# %%
sample = data.loc[0, 'fft_0_b':'fft_749_b']
plt.figure(figsize=(16, 10))
plt.plot(range(len(sample)), sample)
plt.title('Feautures fft_0_b through fft_749_b')
plt.show()

# %%
label_mapping = {'NEGATIVE': 0, 'NEUTRAL': 1, 'POSITIVE': 2}
def preprocess_inputs(df):
  df = df.copy()

  df['label'] = df['label'].replace(label_mapping)

  y = df['label'].copy()
  X = df.drop('label', axis=1).copy()

  X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=123)

  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocess_inputs(data)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Reshape((X_train.shape[1], 1)),

    tf.keras.layers.LSTM(256, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.1),

    tf.keras.layers.LSTM(128, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.1),
    
    tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.1),
    
    tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.1),

    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Dense(3, activation='softmax')
])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 2548, 1)           0
#
#  lstm (LSTM)                 (None, 2548, 256)         264192
#
#  dropout (Dropout)           (None, 2548, 256)         0
#
#  lstm_1 (LSTM)               (None, 2548, 128)         197120
#
#  dropout_1 (Dropout)         (None, 2548, 128)         0
#
#  lstm_2 (LSTM)               (None, 2548, 64)          49408
#
#  dropout_2 (Dropout)         (None, 2548, 64)          0
#
#  lstm_3 (LSTM)               (None, 2548, 64)          33024
#
#  dropout_3 (Dropout)         (None, 2548, 64)          0
#
#  flatten (Flatten)           (None, 163072)            0
#
#  dense (Dense)               (None, 128)               20873344
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 21,425,539
# Trainable params: 21,425,539
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate = 0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=50,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=8,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 28s 508ms/step - loss: 6.5913 - accuracy: 0.7619 - val_loss: 5.0912 - val_accuracy: 0.9197
# Epoch 2/50
# 38/38 [==============================] - 18s 468ms/step - loss: 4.7808 - accuracy: 0.8340 - val_loss: 4.1860 - val_accuracy: 0.8963
# Epoch 3/50
# 38/38 [==============================] - 18s 469ms/step - loss: 3.6663 - accuracy: 0.8852 - val_loss: 3.2074 - val_accuracy: 0.9264
# Epoch 4/50
# 38/38 [==============================] - 18s 467ms/step - loss: 2.8894 - accuracy: 0.9304 - val_loss: 2.5830 - val_accuracy: 0.9298
# Epoch 5/50
# 38/38 [==============================] - 18s 467ms/step - loss: 2.3530 - accuracy: 0.9489 - val_loss: 2.1175 - val_accuracy: 0.9532
# Epoch 6/50
# 38/38 [==============================] - 18s 466ms/step - loss: 1.9378 - accuracy: 0.9614 - val_loss: 1.8338 - val_accuracy: 0.9365
# Epoch 7/50
# 38/38 [==============================] - 18s 467ms/step - loss: 1.6638 - accuracy: 0.9623 - val_loss: 1.6564 - val_accuracy: 0.9231
# Epoch 8/50
# 38/38 [==============================] - 18s 467ms/step - loss: 1.4409 - accuracy: 0.9665 - val_loss: 1.4319 - val_accuracy: 0.9431
# Epoch 9/50
# 38/38 [==============================] - 18s 466ms/step - loss: 1.3031 - accuracy: 0.9581 - val_loss: 1.2561 - val_accuracy: 0.9431
# Epoch 10/50
# 38/38 [==============================] - 18s 466ms/step - loss: 1.1040 - accuracy: 0.9832 - val_loss: 1.1889 - val_accuracy: 0.9365
# Epoch 11/50
# 38/38 [==============================] - 18s 466ms/step - loss: 0.9871 - accuracy: 0.9866 - val_loss: 0.9866 - val_accuracy: 0.9666
# Epoch 12/50
# 38/38 [==============================] - 18s 466ms/step - loss: 0.8747 - accuracy: 0.9908 - val_loss: 0.8962 - val_accuracy: 0.9632
# Epoch 13/50
# 38/38 [==============================] - 18s 466ms/step - loss: 0.8758 - accuracy: 0.9673 - val_loss: 0.8357 - val_accuracy: 0.9666
# Epoch 14/50
# 38/38 [==============================] - 18s 466ms/step - loss: 0.7701 - accuracy: 0.9757 - val_loss: 0.8317 - val_accuracy: 0.9498
# Epoch 15/50
# 38/38 [==============================] - 18s 465ms/step - loss: 0.9006 - accuracy: 0.9288 - val_loss: 1.1816 - val_accuracy: 0.8930
# Epoch 16/50
# 38/38 [==============================] - 18s 468ms/step - loss: 0.7877 - accuracy: 0.9581 - val_loss: 0.7979 - val_accuracy: 0.9298
# Epoch 17/50
# 38/38 [==============================] - 18s 468ms/step - loss: 0.7267 - accuracy: 0.9690 - val_loss: 0.6973 - val_accuracy: 0.9565
# Epoch 18/50
# 38/38 [==============================] - 18s 468ms/step - loss: 0.6141 - accuracy: 0.9732 - val_loss: 0.6049 - val_accuracy: 0.9632
# Epoch 19/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.5481 - accuracy: 0.9841 - val_loss: 0.6806 - val_accuracy: 0.9431
# Epoch 20/50
# 38/38 [==============================] - 18s 466ms/step - loss: 0.4915 - accuracy: 0.9891 - val_loss: 0.5608 - val_accuracy: 0.9699
# Epoch 21/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.4433 - accuracy: 0.9908 - val_loss: 0.6599 - val_accuracy: 0.9565
# Epoch 22/50
# 38/38 [==============================] - 18s 467ms/step - loss: 0.4434 - accuracy: 0.9858 - val_loss: 0.4644 - val_accuracy: 0.9666
# Epoch 23/50
# 38/38 [==============================] - 18s 466ms/step - loss: 0.3769 - accuracy: 0.9983 - val_loss: 0.4098 - val_accuracy: 0.9799
# Epoch 24/50
# 38/38 [==============================] - 18s 466ms/step - loss: 0.3529 - accuracy: 0.9950 - val_loss: 0.3698 - val_accuracy: 0.9732
# Epoch 25/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.3263 - accuracy: 0.9966 - val_loss: 0.4697 - val_accuracy: 0.9431
# Epoch 26/50
# 38/38 [==============================] - 18s 465ms/step - loss: 0.3266 - accuracy: 0.9858 - val_loss: 0.3419 - val_accuracy: 0.9799
# Epoch 27/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.2784 - accuracy: 0.9966 - val_loss: 0.6418 - val_accuracy: 0.9365
# Epoch 28/50
# 38/38 [==============================] - 18s 465ms/step - loss: 0.2944 - accuracy: 0.9849 - val_loss: 0.3011 - val_accuracy: 0.9666
# Epoch 29/50
# 38/38 [==============================] - 18s 466ms/step - loss: 0.2483 - accuracy: 0.9933 - val_loss: 0.2896 - val_accuracy: 0.9799
# Epoch 30/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.2178 - accuracy: 1.0000 - val_loss: 0.3667 - val_accuracy: 0.9632
# Epoch 31/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.2705 - accuracy: 0.9732 - val_loss: 0.3237 - val_accuracy: 0.9599
# Epoch 32/50
# 38/38 [==============================] - 18s 465ms/step - loss: 0.2096 - accuracy: 0.9950 - val_loss: 0.2541 - val_accuracy: 0.9666
# Epoch 33/50
# 38/38 [==============================] - 18s 466ms/step - loss: 0.1774 - accuracy: 0.9992 - val_loss: 0.2464 - val_accuracy: 0.9699
# Epoch 34/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.1616 - accuracy: 1.0000 - val_loss: 0.2597 - val_accuracy: 0.9732
# Epoch 35/50
# 38/38 [==============================] - 18s 466ms/step - loss: 0.1484 - accuracy: 0.9992 - val_loss: 0.2242 - val_accuracy: 0.9632
# Epoch 36/50
# 38/38 [==============================] - 18s 465ms/step - loss: 0.1359 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9699
# Epoch 37/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.1254 - accuracy: 1.0000 - val_loss: 0.2505 - val_accuracy: 0.9732
# Epoch 38/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.1218 - accuracy: 0.9958 - val_loss: 0.3146 - val_accuracy: 0.9565
# Epoch 39/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.4008 - accuracy: 0.9514 - val_loss: 0.4476 - val_accuracy: 0.9030
# Epoch 40/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.2974 - accuracy: 0.9665 - val_loss: 0.4190 - val_accuracy: 0.9431
# Epoch 41/50
# 38/38 [==============================] - 18s 477ms/step - loss: 0.2528 - accuracy: 0.9790 - val_loss: 0.3434 - val_accuracy: 0.9298
# Epoch 42/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.2043 - accuracy: 0.9774 - val_loss: 0.2104 - val_accuracy: 0.9666
# Epoch 43/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.1773 - accuracy: 0.9816 - val_loss: 0.2409 - val_accuracy: 0.9599
# Epoch 44/50
# 38/38 [==============================] - 18s 465ms/step - loss: 0.1425 - accuracy: 0.9925 - val_loss: 0.2097 - val_accuracy: 0.9532

# %%
model_acc = model.evaluate(X_test, y_test, verbose=0)[1]
print(model_acc)
# Out:
# 0.989062488079071

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
y_pred = np.array(list(map(lambda x: np.argmax(x), model.predict(X_test))))

cm = confusion_matrix(y_test, y_pred)
clr = classification_report(y_test, y_pred, target_names=label_mapping.keys())

plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cbar=False, cmap='Blues')
plt.xticks(np.arange(3) + 0.5, label_mapping.keys())
plt.yticks(np.arange(3) + 0.5, label_mapping.keys())
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print(clr)
# Out:
# 20/20 [==============================] - 5s 207ms/step
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.98      0.99      0.98       201
#      NEUTRAL       1.00      1.00      1.00       231
#     POSITIVE       0.99      0.98      0.98       208
#
#     accuracy                           0.99       640
#    macro avg       0.99      0.99      0.99       640
# weighted avg       0.99      0.99      0.99       640
